# %%
#Importing pandas library for reading and using different functions with dataframe
import pandas as pd

# %%
#Reading the dataset and displaying it
df = pd.read_csv('preprocessed_data.csv')
df
# Out:
#        price  status         city    size  equipped  pricePerSquareMeter  \
# 0      15000       0     Prijedor   60.00         0               250.00
# 1      16000       0     Prijedor   57.00         2               280.70
# 2      15000       0      Sokolac   49.00         0               306.12
# 3      57000       1     Derventa  158.00         0               360.76
# 4      15000       0        Celic   40.00         1               375.00
# ...      ...     ...          ...     ...       ...                  ...
# 2830  405000       0       Centar   99.65         0              4064.35
# 2831  195000       0  Grad Mostar   55.19         0              3533.02
# 2832  710000       0       Centar   99.65         0              7125.16
# 2833  390000       0       Centar   75.48         0              5166.80
# 2834  196893       1   Banja Luka   55.19         2              3567.32
#
#         cityShort  count     cityCat  capital  population  year  month  \
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

#Correlation matrix for numerical columns
correlation_matrix = df.corr(numeric_only=True)

plt.figure(figsize=(12, 8))

#Heatmap
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap="coolwarm", cbar=True, square=True)
plt.title("Correlation Matrix Heatmap", fontsize=16)
plt.xticks(rotation=45)
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
#The strongest relationships in the dataset are between price and other size-related features
#size, pricePerSquareMeter, and numOfRooms.

# %%
import matplotlib.pyplot as plt

#Comparison between Big Cities like Banja Luka, Zenica, Tuzla similar against Sarajevo
filtered_df = df[df['cityCat'].isin(['Big Cities', 'Sarajevo'])]

# Group by 'cityCat' and count the number of entries (rows)
city_comparison = filtered_df['cityCat'].value_counts().reset_index()
city_comparison.columns = ['cityCat', 'count']

# Create a bar plot to compare the counts
plt.figure(figsize=(8, 6))
plt.bar(city_comparison['cityCat'], city_comparison['count'], color=['blue', 'orange'])
plt.title('Comparison of Number of Apartments for selling: Big Cities vs Sarajevo')
plt.xlabel('City Category')
plt.ylabel('Number of Apartments')
plt.show()

# %%
import matplotlib.pyplot as plt
#Analysis of Una-Sana Canton
cities_to_compare = ['Bihac', 'Bosanska Krupa', 'Cazin', 'Kljuc', 'Sanski Most', 'Velika Kladusa']
filtered_df = df[df['cityShort'].isin(cities_to_compare)]

# Group by 'cityShort' and count the number of entries (rows)
city_comparison = filtered_df['cityShort'].value_counts().reset_index()
city_comparison.columns = ['cityShort', 'count']

# Create a bar plot to compare the counts
plt.figure(figsize=(10, 6))
plt.bar(city_comparison['cityShort'], city_comparison['count'], color=['blue', 'orange', 'green', 'red', 'pink', 'grey'])
plt.title('Comparison of Number of Apartments being sold in Una-Sana canton')
plt.xlabel('City')
plt.ylabel('Number of Apartments')
plt.show()

# %%
import matplotlib.pyplot as plt
#Analysis of Tuzla Canton
cities_to_compare = ['Banovici', 'Celic', 'Gracanica', 'Gradacac', 'Kalesija', 'Kladanj', 'Lukavac', 'Srebrenik', 'Zivinice', 'Tuzla']
filtered_df = df[df['cityShort'].isin(cities_to_compare)]

# Group by 'cityShort' and count the number of entries (rows)
city_comparison = filtered_df['cityShort'].value_counts().reset_index()
city_comparison.columns = ['cityShort', 'count']

# Create a bar plot to compare the counts
plt.figure(figsize=(10, 6))
plt.bar(city_comparison['cityShort'], city_comparison['count'], color=['blue', 'orange', 'green', 'red', 'pink', 'grey'])
plt.title('Comparison of Number of Apartments being sold in Tuzla canton')
plt.xlabel('City')
plt.ylabel('Number of Apartments')
plt.show()

# %%
import matplotlib.pyplot as plt
#Analysis of Zenica-Doboj Canton
cities_to_compare = ['Vares', 'Breza', 'Tesanj', 'Zepce', 'Zenica', 'Kakanj', 'Visoko']
filtered_df = df[df['cityShort'].isin(cities_to_compare)]

# Group by 'cityShort' and count the number of entries (rows)
city_comparison = filtered_df['cityShort'].value_counts().reset_index()
city_comparison.columns = ['cityShort', 'count']

# Create a bar plot to compare the counts
plt.figure(figsize=(10, 6))
plt.bar(city_comparison['cityShort'], city_comparison['count'], color=['blue', 'orange', 'green', 'red', 'pink', 'grey'])
plt.title('Comparison of Number of Apartments being sold in Zenica-Doboj canton')
plt.xlabel('City')
plt.ylabel('Number of Apartments')
plt.show()

# %%
import matplotlib.pyplot as plt
#Analysis of Srednja Bosna Canton
cities_to_compare = ['Bugojno', 'Jajce', 'Gornji Vakuf - Uskoplje', 'Donji Vakuf', 'Kiseljak', 'Travnik', 'Novi Travnik', 'Vitez']
filtered_df = df[df['cityShort'].isin(cities_to_compare)]

# Group by 'cityShort' and count the number of entries (rows)
city_comparison = filtered_df['cityShort'].value_counts().reset_index()
city_comparison.columns = ['cityShort', 'count']

# Create a bar plot to compare the counts
plt.figure(figsize=(12, 6))
plt.bar(city_comparison['cityShort'], city_comparison['count'], color=['blue', 'orange', 'green', 'red', 'pink', 'grey'])
plt.title('Comparison of Number of Apartments being sold in Srednja Bosna canton')
plt.xlabel('City')
plt.ylabel('Number of Apartments')
plt.show()

# %%
import matplotlib.pyplot as plt
#Analysis of Herzegovina-Neretva Canton
cities_to_compare = ['Capljina', 'Grad Mostar', 'Konjic', 'Neum', 'Ravno' ]
filtered_df = df[df['cityShort'].isin(cities_to_compare)]

# Group by 'cityShort' and count the number of entries (rows)
city_comparison = filtered_df['cityShort'].value_counts().reset_index()
city_comparison.columns = ['cityShort', 'count']

# Create a bar plot to compare the counts
plt.figure(figsize=(10, 6))
plt.bar(city_comparison['cityShort'], city_comparison['count'], color=['blue', 'orange', 'green', 'red', 'pink', 'grey'])
plt.title('Comparison of Number of Apartments being sold in Herzegovina-Neretva canton')
plt.xlabel('City')
plt.ylabel('Number of Apartments')
plt.show()

# %%
import matplotlib.pyplot as plt
#Analysis of West-Herzegovina Canton
cities_to_compare = ['Siroki Brijeg', 'Ljubuski', 'Posusje']
filtered_df = df[df['cityShort'].isin(cities_to_compare)]

# Group by 'cityShort' and count the number of entries (rows)
city_comparison = filtered_df['cityShort'].value_counts().reset_index()
city_comparison.columns = ['cityShort', 'count']

# Create a bar plot to compare the counts
plt.figure(figsize=(10, 6))
plt.bar(city_comparison['cityShort'], city_comparison['count'], color=['blue', 'orange', 'green', 'red', 'pink', 'grey'])
plt.title('Comparison of Number of Apartments being sold in West-Herzegovina canton')
plt.xlabel('City')
plt.ylabel('Number of Apartments')
plt.show()

# %%
import matplotlib.pyplot as plt
#Analysis of Sarajevo Canton
cities_to_compare = ['Ilidza', 'Ilijas', 'Vogosca', 'Sarajevo', 'Hadzici']
filtered_df = df[df['cityShort'].isin(cities_to_compare)]

# Group by 'cityShort' and count the number of entries (rows)
city_comparison = filtered_df['cityShort'].value_counts().reset_index()
city_comparison.columns = ['cityShort', 'count']

# Create a bar plot to compare the counts
plt.figure(figsize=(10, 6))
plt.bar(city_comparison['cityShort'], city_comparison['count'], color=['blue', 'orange', 'green', 'red', 'pink', 'grey'])
plt.title('Comparison of Number of Apartments being sold in Sarajevo canton')
plt.xlabel('City')
plt.ylabel('Number of Apartments')
plt.show()

# %%
import matplotlib.pyplot as plt
#Analysis of Brcko District, Gorazde and Livno Canton
cities_to_compare = ['Brcko', 'Kupres', 'Gorazde']
filtered_df = df[df['cityShort'].isin(cities_to_compare)]

# Group by 'cityShort' and count the number of entries (rows)
city_comparison = filtered_df['cityShort'].value_counts().reset_index()
city_comparison.columns = ['cityShort', 'count']

# Create a bar plot to compare the counts
plt.figure(figsize=(10, 6))
plt.bar(city_comparison['cityShort'], city_comparison['count'], color=['blue', 'orange', 'green', 'red', 'pink', 'grey'])
plt.title('Comparison of Number of Apartments being sold in different cantons and district')
plt.xlabel('City')
plt.ylabel('Number of Apartments')
plt.show()

# %%
import matplotlib.pyplot as plt
#Analysis of Western RS
cities_to_compare = ['Banja Luka', 'Celinac','Gradiska', 'Kotor Varos', 'Kozarska Dubica'
                        'Laktasi', 'Mrkonjic Grad', 'Prijedor', 'Ribnik', 'Knezevo']
filtered_df = df[df['cityShort'].isin(cities_to_compare)]

# Group by 'cityShort' and count the number of entries (rows)
city_comparison = filtered_df['cityShort'].value_counts().reset_index()
city_comparison.columns = ['cityShort', 'count']

# Create a bar plot to compare the counts
plt.figure(figsize=(10, 6))
plt.bar(city_comparison['cityShort'], city_comparison['count'], color=['blue', 'orange', 'green', 'red', 'pink', 'grey'])
plt.title('Comparison of Number of Apartments being sold in Western RS')
plt.xlabel('City')
plt.ylabel('Number of Apartments')
plt.show()

# %%
import matplotlib.pyplot as plt
#Analysis of Northern RS
cities_to_compare = ['Brod', 'Derventa', 'Doboj', 'Samac', 'Srbac', 'Stanari', 'Teslic', 'Modrica']
filtered_df = df[df['cityShort'].isin(cities_to_compare)]

# Group by 'cityShort' and count the number of entries (rows)
city_comparison = filtered_df['cityShort'].value_counts().reset_index()
city_comparison.columns = ['cityShort', 'count']

# Create a bar plot to compare the counts
plt.figure(figsize=(10, 6))
plt.bar(city_comparison['cityShort'], city_comparison['count'], color=['blue', 'orange', 'green', 'red', 'pink', 'grey'])
plt.title('Comparison of Number of Apartments being sold in Northern RS')
plt.xlabel('City')
plt.ylabel('Number of Apartments')
plt.show()

# %%
import matplotlib.pyplot as plt
#Analysis of Northern RS
cities_to_compare = ['Bijeljina', 'Bratunac', 'Han Pijesak', 'Lopare', 'Lukavica'
    'Milići', 'Pale', 'Rogatica', 'Sokolac', 'Srebrenica', 'Visegrad', 'Vlasenica', 'Zvornik']
filtered_df = df[df['cityShort'].isin(cities_to_compare)]

# Group by 'cityShort' and count the number of entries (rows)
city_comparison = filtered_df['cityShort'].value_counts().reset_index()
city_comparison.columns = ['cityShort', 'count']

# Create a bar plot to compare the counts
plt.figure(figsize=(12, 6))
plt.bar(city_comparison['cityShort'], city_comparison['count'], color=['blue', 'orange', 'green', 'red', 'pink', 'grey'])
plt.title('Comparison of Number of Apartments being sold in Northern RS')
plt.xlabel('City')
plt.ylabel('Number of Apartments')
plt.show()

# %%
import matplotlib.pyplot as plt
#Analysis of Southern RS
cities_to_compare = ['Foca', 'Gacko', 'Trebinje', 'Rudo', 'Cajnice']
filtered_df = df[df['cityShort'].isin(cities_to_compare)]

# Group by 'cityShort' and count the number of entries (rows)
city_comparison = filtered_df['cityShort'].value_counts().reset_index()
city_comparison.columns = ['cityShort', 'count']

# Create a bar plot to compare the counts
plt.figure(figsize=(10, 6))
plt.bar(city_comparison['cityShort'], city_comparison['count'], color=['blue', 'orange', 'green', 'red', 'pink', 'grey'])
plt.title('Comparison of Number of Apartments being sold in Southern RS')
plt.xlabel('City')
plt.ylabel('Number of Apartments')
plt.show()

# %%
import matplotlib.pyplot as plt
#Analysis of City of Sarajevo
cities_to_compare = ['Novi Grad', 'Novo Sarajevo', 'Centar', 'Stari Grad']
filtered_df = df[df['city'].isin(cities_to_compare)]

# Group by 'cityShort' and count the number of entries (rows)
city_comparison = filtered_df['city'].value_counts().reset_index()
city_comparison.columns = ['city', 'count']

# Create a bar plot to compare the counts
plt.figure(figsize=(10, 6))
plt.bar(city_comparison['city'], city_comparison['count'], color=['blue', 'orange', 'green', 'red', 'pink', 'grey'])
plt.title('Comparison of Number of Apartments being sold in City of Sarajevo')
plt.xlabel('City')
plt.ylabel('Number of Apartments')
plt.show()

# %%
import matplotlib.pyplot as plt
#Analysis of City of East Sarajevo
cities_to_compare = ['Pale', 'Istocni Stari Grad', 'Lukavica']
filtered_df = df[df['city'].isin(cities_to_compare)]

# Group by 'cityShort' and count the number of entries (rows)
city_comparison = filtered_df['city'].value_counts().reset_index()
city_comparison.columns = ['city', 'count']

# Create a bar plot to compare the counts
plt.figure(figsize=(10, 6))
plt.bar(city_comparison['city'], city_comparison['count'], color=['blue', 'orange', 'green', 'red', 'pink', 'grey'])
plt.title('Comparison of Number of Apartments being sold in City of East Sarajevo')
plt.xlabel('City')
plt.ylabel('Number of Apartments')
plt.show()

# %%
import matplotlib.pyplot as plt

#Taking biggest cities in Bosnia and Herzegovina to analyze
cities_to_compare = ['Bihac', 'Tuzla', 'Zenica', 'Travnik', 'Grad Mostar', 'Ljubuski', 'Brcko',
                    'Banja Luka', 'Doboj', 'Bijeljina', 'Trebinje', 'Sarajevo', 'Lukavica']
filtered_df = df[df['cityShort'].isin(cities_to_compare)]

# Group by 'cityShort' and count the number of entries (rows)
city_comparison = filtered_df['cityShort'].value_counts().reset_index()
city_comparison.columns = ['cityShort', 'count']

# Create a bar plot to compare the counts
plt.figure(figsize=(14, 8))
plt.bar(city_comparison['cityShort'], city_comparison['count'], color=['blue', 'orange', 'green', 'red', 'pink', 'grey'])
plt.title('Comparison of Number of Apartments being sold in biggest cities from diff regions')
plt.xlabel('City')
plt.ylabel('Number of Apartments')
plt.show()

# %%
import matplotlib.pyplot as plt

#Taking biggest cities in Bosnia and Herzegovina to analyze
cities_to_compare = ['Neum', 'Jajce', 'Travnik', 'Mostar', 'Trebinje', 'Konjic']
filtered_df = df[df['cityShort'].isin(cities_to_compare)]

# Group by 'cityShort' and count the number of entries (rows)
city_comparison = filtered_df['cityShort'].value_counts().reset_index()
city_comparison.columns = ['cityShort', 'count']

# Create a bar plot to compare the counts
plt.figure(figsize=(14, 8))
plt.bar(city_comparison['cityShort'], city_comparison['count'], color=['blue', 'orange', 'green', 'red', 'pink', 'grey'])
plt.title('Comparison of Number of Apartments being sold in touristical cities')
plt.xlabel('City')
plt.ylabel('Number of Apartments')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 5
#       3 #Taking biggest cities in Bosnia and Herzegovina to analyze
#       4 cities_to_compare = ['Neum', 'Jajce', 'Travnik', 'Mostar', 'Trebinje', 'Konjic']
# ----> 5 filtered_df = df[df['cityShort'].isin(cities_to_compare)]
#       7 # Group by 'cityShort' and count the number of entries (rows)
#       8 city_comparison = filtered_df['cityShort'].value_counts().reset_index()
#
# NameError: name 'df' is not defined
